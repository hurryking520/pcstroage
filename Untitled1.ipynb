# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt

# %%
engine = create_engine('mysql+pymysql://root:210518aA@localhost:3306/stocks')

# %%
sql='select * from ping_result_pgw where f1=\'E-UTRAN\' and f4=\'Ping测试时延\' and f5=\'成功\''

# %%
df_read=pd.read_sql_query(sql,engine)
print("1")
# Out:
# C:\Users\Seymour520\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 1")
#   result = self._query(query)
# 1

# %%
province_gb=df_read.groupby("f2")

# %%
for pro_name,pro_group in province_gb:
    pro_group_by_name=province_gb.get_group('湖北')
    #print(pro_group_by_name)  ##单个省的数据
    pgw_gb=pro_group_by_name.groupby("F9")
    for pgw_name,pgw_group in pgw_gb:
        pro_to_pgw_by_name=pgw_gb.get_group('东区')
        pro_to_pgw_by_name['f6']=pro_to_pgw_by_name["f6"].astype("float")
        pro_to_pgw_by_name=pro_to_pgw_by_name.sort_values(by="f6",ascending=False)
        pro_to_pgw_by_name.boxplot()
        print()
        plt.show()
        ###上面程序完成排序，由大到小
        delay_values=pro_to_pgw_by_name['f6'].values
        #print(delay_values)
        count=delay_values.size
        break
f1.close()
# Out:
# C:\Users\Seymour520\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Seymour520\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Seymour520\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
